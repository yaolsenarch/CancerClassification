# %%
from xgboost import XGBClassifier
XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c34fd30daa56> in <module>
# ----> 1 from xgboost import XGBClassifier
#       2 XGBClassifier()
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X=pd.DataFrame(data.data, columns=data.feature_names)
y=data.target
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.2)

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report
print(accurancy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
pd.crosstab(y_test, y_predict)

# %%
#this one gives accuracy of 0.9824
model = XGBClassifier(max_depth = 3 #default 6?, deep enough  
                      subsample = 0.8#default 1
                      n_estimators =100, 
                      learning_rate = 0.1,
                      min_child_weight = 1,
                      random_state = 5
                     )
#this one gives accuracy of 0.99
model = XGBClassifier(max_depth = 3 #default ?, deep enough  
                      subsample = 0.8#default 1
                      n_estimators =100*2, 
                      learning_rate = 0.1/2,
                      min_child_weight = 1,
                      random_state = 5, #not a parameter
                      reg_alpha = 0,
                      reg_lambda = 1
                     )
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_train_predict = model.predict(X_train)
from sklearn.metrics import accuracy_score, classification_report
print('Train accuracy', accurancy_score(y_test, y_predict))
print('Test accuracy', accurancy_score(y_test, y_predict))
print(classification_report(y_test, y_predict))
pd.crosstab(y_test, y_predict)
